# %% [markdown]
# Can Use python Docs to refer.
# Use PyPDF2 for pdf operations
#       https://pypdf2.readthedocs.io/en/3.x/

# %% [markdown]
# Flask
#   Framework for HTML CSS and JS - Bootstrap
#     https://getbootstrap.com/docs/5.3/getting-started/introduction/
